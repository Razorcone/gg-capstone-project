# %%
import torch
import torch.nn as nn
import torch.optim as optim

from torchtext.legacy.data import Field, BucketIterator, TabularDataset

import spacy
import numpy as np

import random
import math
import time

import csv

BATCH_SIZE = 128
N_EPOCHS = 10
CLIP = 1
SEED = 1234
PRINT_CHAT = True

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

spacy_en = spacy.load("en_core_web_sm")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def tokenize_en(text):
    """
    Tokenizes English text from a string into a list of strings
    """
    return [tok.text for tok in spacy_en.tokenizer(text)]


SRC = Field(tokenize=tokenize_en,
            init_token='<sos>',
            eos_token='<eos>',
            lower=True)

TRG = Field(tokenize=tokenize_en,
            init_token='<sos>',
            eos_token='<eos>',
            lower=True)

data_fields = [('src', SRC), ('trg', TRG)]

# %%
def train_validate_test_split(df, train_percent=.6, validate_percent=.2, seed=None):
    np.random.seed(seed)
    perm = np.random.permutation(df.index)
    m = len(df.index)
    train_end = int(train_percent * m)
    validate_end = int(validate_percent * m) + train_end
    train = df.iloc[perm[:train_end]]
    validate = df.iloc[perm[train_end:validate_end]]
    test = df.iloc[perm[validate_end:]]
    return train, validate, test

train_data, validation_data, test_data = TabularDataset.splits(
    path='datasets/',
    format='csv',
    train='data_train.csv',
    validation='data_validation.csv',
    test='data_test.csv',
    skip_header=False,
    fields=data_fields)

SRC.build_vocab(train_data, min_freq = 2, vectors="glove.6B.200d")
TRG.build_vocab(train_data, min_freq = 2, vectors="glove.6B.200d")

train_iterator, validation_iterator, test_iterator = BucketIterator.splits(
    (train_data, validation_data, test_data),
    batch_size=BATCH_SIZE,
    sort_key=lambda x: len(x.src),  # function used to group the data
    sort_within_batch=False,
    device=device)

# %%
# print chatbot's words
def print_chat(sentences):
    print("chatbot: ", end="")
    for word_embeds in sentences:
        word_embed = word_embeds[0]
        # find one shot index from word embedding

        # one_shot_idx = 0
        # for idx in range(len(word_embed)):
        #     if word_embed[idx] > word_embed[one_shot_idx]:
        #         one_shot_idx = idx

        max_idx_t = word_embed.argmax()
        max_idx = max_idx_t.item()
        word = TRG.vocab.itos[max_idx]
        print(word, end=" ")
    print("")  # new line at the end of sentence

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, hid_dim, dropout):
        super().__init__()

        self.hid_dim = hid_dim

        # use pre-trained word embeddings
        self.embedding = nn.Embedding(input_dim, emb_dim)
        weight_matrix = SRC.vocab.vectors
        self.embedding.weight.data.copy_(weight_matrix)

        self.rnn = nn.GRU(emb_dim, hid_dim)

    def forward(self, src):
        # src = [src len, batch size]

        embedded = self.embedding(src)

        # embedded = [src len, batch size, emb dim]

        outputs, hidden = self.rnn(embedded)  # no cell state!

        # outputs = [src len, batch size, hid dim * n directions]
        # hidden = [n layers * n directions, batch size, hid dim]

        # outputs are always from the top hidden layer

        return hidden


class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, hid_dim, dropout):
        super().__init__()

        self.hid_dim = hid_dim
        self.output_dim = output_dim

        # use pre-trained word embeddings
        self.embedding = nn.Embedding(output_dim, emb_dim)
        weight_matrix = TRG.vocab.vectors
        self.embedding.weight.data.copy_(weight_matrix)

        self.rnn = nn.GRU(emb_dim + hid_dim, hid_dim)

        self.fc_out = nn.Linear(emb_dim + hid_dim * 2, output_dim)

        self.dropout = nn.Dropout(dropout)

    def forward(self, input, hidden, context):
        # input = [batch size]
        # hidden = [n layers * n directions, batch size, hid dim]
        # context = [n layers * n directions, batch size, hid dim]

        # n layers and n directions in the decoder will both always be 1, therefore:
        # hidden = [1, batch size, hid dim]
        # context = [1, batch size, hid dim]

        input = input.unsqueeze(0)

        # input = [1, batch size]

        embedded = self.embedding(input)

        # embedded = [1, batch size, emb dim]

        emb_con = torch.cat((embedded, context), dim=2)

        # emb_con = [1, batch size, emb dim + hid dim]

        output, hidden = self.rnn(emb_con, hidden)

        # output = [seq len, batch size, hid dim * n directions]
        # hidden = [n layers * n directions, batch size, hid dim]

        # seq len, n layers and n directions will always be 1 in the decoder, therefore:
        # output = [1, batch size, hid dim]
        # hidden = [1, batch size, hid dim]

        output = torch.cat((embedded.squeeze(0), hidden.squeeze(0), context.squeeze(0)),
                           dim=1)
        output = self.dropout(output)  # dropout the fc layer

        # output = [batch size, emb dim + hid dim * 2]

        prediction = self.fc_out(output)

        # prediction = [batch size, output dim]

        return prediction, hidden

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()

        self.encoder = encoder
        self.decoder = decoder
        self.device = device

        assert encoder.hid_dim == decoder.hid_dim, \
            "Hidden dimensions of encoder and decoder must be equal!"

    def forward(self, src, trg, teacher_forcing_ratio=0.8):
        # src = [src len, batch size]
        # trg = [trg len, batch size]
        # teacher_forcing_ratio is probability to use teacher forcing
        # e.g. if teacher_forcing_ratio is 0.75 we use ground-truth inputs 75% of the time

        batch_size = trg.shape[1]
        trg_len = trg.shape[0]
        trg_vocab_size = self.decoder.output_dim

        # tensor to store decoder outputs
        outputs = torch.zeros(trg_len, batch_size, trg_vocab_size).to(self.device)

        # last hidden state of the encoder is the context
        context = self.encoder(src)

        # context also used as the initial hidden state of the decoder
        hidden = context

        # first input to the decoder is the <sos> tokens
        input = trg[0, :]

        for t in range(1, trg_len):
            # insert input token embedding, previous hidden state and the context state
            # receive output tensor (predictions) and new hidden state
            output, hidden = self.decoder(input, hidden, context)

            # place predictions in a tensor holding predictions for each token
            outputs[t] = output

            # decide if we are going to use teacher forcing or not
            teacher_force = random.random() < teacher_forcing_ratio

            # get the highest predicted token from our predictions
            top1 = output.argmax(1)

            # if teacher forcing, use actual next token as next input
            # if not, use predicted token
            input = trg[t] if teacher_force else top1

        if PRINT_CHAT:
            print_chat(outputs)
        return outputs

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)
ENC_EMB_DIM = 200
DEC_EMB_DIM = 200
HID_DIM = 512
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, DEC_DROPOUT)
model = Seq2Seq(enc, dec, device).to(device)

# %%
def freeze_layers(layers):
    for layer in layers:
        for name, value in layer.named_parameters():
            value.requires_grad = False


# freeze the embedding parameters
freeze_layers([model.encoder.embedding, model.decoder.embedding])


def init_weights(model):
    for name, param in model.named_parameters():
        if param.requires_grad:
            nn.init.normal_(param.data, mean=0, std=0.01)


init_weights(model)

# print the model structure
print(model)


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


print(f'The model has {count_parameters(model):,} trainable parameters')

optimizer = optim.Adam(model.parameters())

TRG_PAD_IDX = TRG.vocab.stoi[TRG.pad_token]

criterion = nn.CrossEntropyLoss(ignore_index=TRG_PAD_IDX)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(3681, 200)
#     (rnn): GRU(200, 512)
#   )
#   (decoder): Decoder(
#     (embedding): Embedding(3694, 200)
#     (rnn): GRU(712, 512)
#     (fc_out): Linear(in_features=1224, out_features=3694, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )
# The model has 7,504,990 trainable parameters

# %%
def train(model, iterator, optimizer, criterion, clip):
    model.train()

    epoch_loss = 0
    for i, batch in enumerate(iterator):
        src = batch.src
        trg = batch.trg

        optimizer.zero_grad()

        output = model(src, trg)

        # trg = [trg len, batch size]
        # output = [trg len, batch size, output dim]

        output_dim = output.shape[-1]

        output = output[1:].view(-1, output_dim)
        trg = trg[1:].view(-1)

        # trg = [(trg len - 1) * batch size]
        # output = [(trg len - 1) * batch size, output dim]
        loss = criterion(output, trg)

        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)

        optimizer.step()

        epoch_loss += loss.item()

    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    model.eval()

    epoch_loss = 0

    with torch.no_grad():
        for i, batch in enumerate(iterator):
            src = batch.src
            trg = batch.trg

            output = model(src, trg, 0)  # turn off teacher forcing

            # trg = [trg len, batch size]
            # output = [trg len, batch size, output dim]

            output_dim = output.shape[-1]

            output = output[1:].view(-1, output_dim)
            trg = trg[1:].view(-1)

            # trg = [(trg len - 1) * batch size]
            # output = [(trg len - 1) * batch size, output dim]

            loss = criterion(output, trg)

            epoch_loss += loss.item()

    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs


def train_epoch(n_epochs):
    best_validation_loss = float('inf')

    for epoch in range(n_epochs):
        start_time = time.time()

        train_loss = train(model, train_iterator, optimizer, criterion, CLIP)
        #validation_loss = evaluate(model, validation_iterator, criterion)

        end_time = time.time()

        epoch_mins, epoch_secs = epoch_time(start_time, end_time)

        # if validation_loss < best_validation_loss:
        #     best_validation_loss = validation_loss
        #     torch.save(model.state_dict(), 'chatbot_rnn-model.pt')

        print(f'Epoch: {epoch + 1:02} | Time: {epoch_mins}m {epoch_secs}s')
        print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
        #print(f'\t Val. Loss: {validation_loss:.3f} |  Val. PPL: {math.exp(validation_loss):7.3f}')

    torch.save(model.state_dict(), 'datasets/chatbot_rnn-model.pt')

# %%
def create_chat_csv(filename, sentence):
    f_csv = open("datasets/" + filename + '.csv', 'w', encoding='utf-8', newline='')
    csv_writer = csv.writer(f_csv)
    csv_writer.writerow([sentence, sentence])


def talk(num):
    for i in range(num):
        user_input = input("user: ")
        create_chat_csv("chat", user_input)
        test_data = TabularDataset(
            path='datasets/chat.csv',
            format='csv',
            skip_header=False,
            fields=data_fields)
        test_iterator = BucketIterator(
            test_data,
            batch_size=BATCH_SIZE,
            sort_key=lambda x: len(x.src),
            sort_within_batch=False,
            device=device)
        evaluate(model, test_iterator, criterion)

# %%
train_epoch(2)
model = Seq2Seq(enc, dec, device).to(device)
model.load_state_dict(torch.load('datasets/chatbot_rnn-model.pt'))

#test_loss = evaluate(model, test_iterator, criterion)
#print(f'| Test Loss: {test_loss:.3f} | Test PPL: {math.exp(test_loss):7.3f} |')
# Out:
# chatbot: <unk>   tidak ketika tidak tempat lakilaki untuk membenci dan seorang wanita <eos> membawanya keluar pada <eos> dan
# chatbot: <unk>   <unk> pisau anak itu <eos> <eos> yang yang <eos> yang sama <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   annie <eos> <eos> <eos> suka <eos> <eos> <eos> <eos> morg <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku senang bisa pulang <eos> <eos> <eos> kamu <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   sekarang sedang <eos> pekerjaan yang indah <eos> <eos> tahun yang yang el <eos> <eos> <eos> <eos>
# chatbot: <unk>   iya ingin bertemu denganmu satu <eos> <eos> iya <eos> <eos> <eos> <eos> <eos> iya <eos> <eos>
# chatbot: <unk>   <unk>   martin <eos> <unk> <eos> <eos> dalam <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   wanitamu   orang orang orang <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku <eos> bertemu <eos> satu <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> denganmu
# chatbot: <unk>   hai   yo <eos> yo <eos> <eos> kami <eos> akan <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   oh <eos> brilian <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kamu ditempat yang off <eos> <eos> <eos> <eos> <eos> <eos> kamu batu " <eos> <eos>
# chatbot: <unk>   <unk> bersih waktu bersih yang <unk> <eos> di <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kamu becanda <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   itu bagus <eos> <eos> <eos> itu itu itu <eos> <eos> itu <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   itu <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   <unk> <eos> <eos> <eos> <eos> <eos> atas hidupku <eos> hidupku   tidak <unk> <eos> <unk>
# chatbot: <unk>   aku papaku kubayangkan kamu kamu lakukan kamu ini <eos> <eos> <eos> <eos> lolos <eos> <eos> <eos>
# chatbot: <unk>   iya   benar <eos> <eos> <eos> <eos> <eos> aku benar <eos> <eos> <eos> <eos> ini <eos>
# chatbot: <unk>   aku mengerti betapa aku untuk harus untuk melakukan <eos> ini <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku tidak <eos> <eos> tidak sadar <eos> aku kamu ia sesuatu sama muda <eos> <eos> <eos>
# chatbot: <unk>   aku cuma jadi kenyataan <eos> tentang ke <eos> <eos> dan semua dan dan <eos> saat <eos>
# chatbot: <unk>   nikki dan aku hidup di jalanan ketika kami menemukan parkour <eos> <eos> parkour <eos> jalanan <eos>
# chatbot: <unk>   dah tinggal <eos> <eos> <eos> <eos> <eos> <eos> <eos> dokter <eos> <eos> nona <eos> <eos> <eos>
# chatbot: <unk>   aku hanya seorang pekerja <eos> <eos> <eos> kamu <eos> kamu <eos> kamu <eos> <eos> <eos> <eos>
# chatbot: <unk>   mereka beri bunuh untukmu <eos> <eos> aku <eos> <eos> kakekku wanita yang <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku annie <eos> <eos> ibu <eos> <eos> ok lalu <eos> ibu <eos> annie <eos> <eos> <eos>
# chatbot: <unk>   menara yerusalem mencapai <eos> <eos> tahun <eos> mencapai <eos> mencapai <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku merubah daratan ke nan hijau di utara <eos> <eos> zona <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   laura   dia saudaraku <eos> <eos> bahan <eos> <eos> <eos> <eos> <eos> " <eos> <eos> <eos>
# chatbot: <unk>   kamu <eos> <eos> <eos> atau <unk> <eos> dan kamu tidak berada di un <eos> <eos> <eos>
# chatbot: <unk>   di masa depan <eos>   atau tahun tahun yang <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku dengar berpikir jenis anak itu ada hubungannya dengan juri <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   pagar sekarang <eos> berburu sheriff   seharusnya <eos> <eos> <eos> pagar <eos> oke <eos> <eos> <eos>
# chatbot: <unk>   mengapa kamu tidak tinggal di sini bersama kami <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   itu pasti lagi bukan <eos> <eos> <eos> <eos> <eos> bukan <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   apa seperti yang aku lakukan <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   begini akan bu <eos> <eos> <eos> <eos> <eos> <eos> sekolah <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   tapi tahu   tapi setiap setiap banyak pasti   pasti ada <eos>   kamu pasti <eos>
# chatbot: <unk>   beberapa beberapa orang yang cukup aneh di sana <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku menemanimu <unk> memohon membuatmu saja tinggal <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   itu kesaksian yang paling penting <eos> <eos> <eos> <eos> paling <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kurasa kami berhutang padanya beberapa patah kata   hanya itu <eos> <eos> <eos> <eos> kami kami <eos>
# chatbot: <unk>   mereka terakhir nak <eos> pergi <eos> <eos> <eos> <eos> ke <unk> <eos> sesuatu di <eos> <eos>
# chatbot: <unk>   setidaknya tidak serius <eos> <eos> <eos> <eos> aku <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   apa doc   apa <eos> <eos> <eos> <eos> ini <eos> ini <eos> <eos> <eos>
# chatbot: <unk>   duduklah kamu tidak <unk> dengan baik   <unk> kamu   <unk> <unk> <eos> <eos> <unk> <eos>
# chatbot: <unk>   kenapa kamu butuh kunci mobil <eos> kamu <eos> melalui mobil <eos> <eos> <eos> <eos> <eos> mobil
# chatbot: <unk>   aku kira aku bicara <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku senang <eos> <eos> <eos> bukan <eos> <eos> <eos> ayahku <eos> ini <eos> <eos> <eos> <eos>
# chatbot: <unk>   sekarang   itu <eos> <eos> <eos> <eos> <eos> itu <eos> <eos> <eos> <eos> <eos> <eos> lalu
# chatbot: <unk>   banyak tuduhan terhadap mereka <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   annie <eos> <eos> <eos> sedikit <eos> <eos> annie <eos> panas <eos> annie <eos> parker <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   oh kakekmu <unk> di <unk> kan <eos> kan <eos> ada <eos> <eos> <eos> <eos> kan <eos> <eos>
# chatbot: <unk>   kamu mengikuti dia <eos> <eos> <eos> <eos> bagus <eos> <eos> dia <eos> <eos> <eos> <eos> kamu
# chatbot: <unk>   tapi sangat menyayangi mereka <eos> cari <eos> cari cari <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   bogardus   kamu tidak apaapa <eos> <eos> <eos> bagaimana <eos> <eos> bukan <eos> <eos> <eos> <eos>
# chatbot: <unk>   kamu tidak mencintainya <unk> <eos> <eos> dia tempat <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kamu tahu kakek <unk> <eos> <unk> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   lihat <eos> aku <eos> <eos> <eos> aku <eos> lihat tahun <eos> <eos> tapi tahun <eos> <eos>
# chatbot: <unk>   beruntung beruntung mendapatkan mereka pembunuhan <eos> pembunuhan apa <eos> <eos> pembunuhan <eos> <eos> pembunuhan <eos> <eos>
# chatbot: <unk>   kamu tidak <eos> <eos> <eos> <eos> di sesuatu <eos> <eos> di konyol di di <eos> <eos>
# chatbot: <unk>   aku tidak jelaskan kenapa ibu di sini <eos> <eos> lalu <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku akan jika kamu akan menunjukkan <eos> jika <eos> jika <eos> kamu <eos> <eos> <eos> kamu
# chatbot: <unk>   dokumen <eos> <eos> <eos> <eos> <eos> <eos> dokumen <eos> <eos> <eos> <eos> dokumen <eos> <eos> <eos>
# chatbot: <unk>   ungkapan picketfs <eos> <eos> <eos> masuk ini kereta ditinggikan <eos> tengah <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   tutup matamu <eos> matamu <eos> <eos> tahun <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   president kim <eos> <eos> lagi <eos> sekarang <eos> <eos> <eos> <eos> sebuah lubang <eos> <eos> <eos>
# chatbot: <unk>   tidak perlu jadi pemburu untuk keras <eos> <eos> untuk <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku dalam konstitusi   dia <eos> <eos> <eos> tidak <eos> <eos> dalam rangka <eos> <eos> <eos>
# chatbot: <unk>   kalian aku kubuat <unk> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   well   di sini mereka datang <eos> sini <eos> di tahu <eos> <eos> keluar <eos> <eos>
# chatbot: <unk>   mereka tidak aman mereka menuju menuju kemari <eos> kemari <eos> <eos> <eos> kemari <eos> <eos> <eos>
# chatbot: <unk>   menurutku akhirat hanya <unk> orang saja <eos> saja <eos> <eos> <eos> <eos> <eos> <eos> saja <eos>
# chatbot: <unk>   bagaimana ada telah menyebar diri <eos> <unk> dunia <eos> <eos> dunia <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   seberapa <eos> well <eos> banyak <eos> yang akan ada <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   ada hal yang yang ingin bicarakan bicarakan <eos> <eos> <eos> bicarakan bicarakan tersebut <eos> penting <eos>
# chatbot: <unk>   jika masing masing   dari lagi <eos> pria <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   iya <unk> of this <unk> <unk> you <unk> <unk> <eos> <unk> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   bordeaux <eos> yang lama <eos> <eos> seperti <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku tidak melihatnya dengan spesial khusus <eos> <eos>   kami bicara tempat musim " <eos> <eos>
# chatbot: <unk>   maksudku   hallie   annie <eos> <eos> <eos> <eos> hallie <eos> hallie <eos> <eos> <eos> <eos>
# chatbot: <unk>   hai kamu akan hari hal <eos> <eos> <eos> <eos> sayang <eos> <eos> <eos> sayang <eos>
# chatbot: <unk>   balapan papa rumah   ayah <eos> <eos> <eos> papa <eos> <eos> ayah <eos> <eos> <eos> <eos>
# chatbot: <unk>   kamu cuma jorok dirinya <eos> <eos> <eos> <eos> <eos> sama ditunjuk <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   dia cantik dan fun   aku aku suka <unk> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku sudah tidak bertemu dengannya dua tahun terakhir <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   sekarang kamu <unk> desainer <eos> desainer kamu dalam desainer <eos> <eos> kamu <unk>
# chatbot: <unk>   kamu <eos> <eos> kami lihat saja ini <eos> <eos> <eos> <eos> <eos> sesuatu sesuatu lain <eos>
# chatbot: <unk>   aku tahu itu <eos> <eos> <eos> <eos> faktanya <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku tidak membuat <eos> ini <eos> <eos> <eos> <eos> <eos> sama <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku ingin merindukanmu   ratu hatiku <eos> ratu   ratu ratu ratu <eos> <eos> <eos> ibu
# chatbot: <unk>   aku   aku bingung <eos> <eos> <eos> <eos> <eos> akan akan <unk> kalian akan <eos> <eos>
# chatbot: <unk>   aku tahu   <eos> <eos> <eos> <eos> <eos> anak hidup dengan ini sebuah <unk> <eos> <eos>
# chatbot: <unk>   tentu banyak daging sapi akan tersedia disini <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kami akan kami menderita gangguan tenggorokan jika kami teruskan ini <eos> <eos> <eos> tenggorokan kami <eos>
# chatbot: <unk>   baik   dengarkan <eos> <eos> dengarkan <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   besok beruntung kan <eos> yang amat <eos> malam <eos> <eos> masih <eos> bisa kulakukan senjata "
# chatbot: <unk>   girls   kubilang padamu   terimalah ini terimalah ini <eos> kemauannya <eos> kemauannya <eos> <eos> <eos>
# chatbot: <unk>   kamu punya anak <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku hanya pasti mengadopsinya mengadopsinya <eos> <eos> <eos> <eos> jika terjadi <eos> padamu <eos> <eos> <eos>
# chatbot: <unk>   lane lane <unk>   aku   jameson <eos> <eos> aku suka <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   ia memanggil polisi <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   membuka kakekku <eos> ambilah <eos> <eos> <eos> belum pernah <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku bersumpah pada <unk>   jika terjadi akan saja aku akan menerima hukuman <eos> <eos> hukuman
# chatbot: <unk>   mereka saja   kami <eos> tuduhan tuduhan positif sajikan    tentu tingkat pertama di di pertama
# chatbot: <unk>   dan kami semua tahu itu hanya juga <eos> <eos> <eos> dia <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   sepertinya tidak bisa keluar dari seluruh di cepat <eos> iya <eos> berdiri di cepat <eos> <eos>
# chatbot: <unk>   hai sekelompok ini <eos> <eos> <eos> <eos> <eos> <eos> <eos> dengan <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   selamat <eos> <eos> <eos> <eos> selamat <eos> <eos> selamat <eos> selamat <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   tidak bisa   maaf <eos> bisa <eos> <eos> tapi <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kamu   gerry   aku akan pindah pegunungan untuk mendapatkan   di sini <eos> <eos> malam
# chatbot: <unk>   dan dan selalu berkata ayah <eos> <eos> berkata <eos> dan <eos> dan <eos> dan <eos> <eos>
# chatbot: <unk>   ini   <unk> <eos> <unk> padaku ini ini <eos> hal ini ini ini <eos> <eos> <eos>
# chatbot: <unk>   tutup tidak pengecut sepertimu melebihi apapun <eos> <eos> <eos> aku   aku dan aku <eos> <eos>
# chatbot: <unk>   beri aku waktu beberapa minggu   aku akan mendapatkan uang untuk untuk kamu <eos> <eos> <eos>
# chatbot: <unk>   bukankah ia menjadi takut ditangkap <eos> takut <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku tidak bisa sendirian <eos> kawan <eos> <eos> <eos> <eos> mendengarkan sama kamu <eos> <eos> <eos>
# chatbot: <unk>   kamu kamu melihatmu jam <eos> yang harus <eos> ketika ketika kami   ini <eos> <eos> <eos>
# chatbot: <unk>   minggirlah   hallie <eos> <eos> <eos> hallie <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   " duduk <eos> jernih <eos> dan pergi untuk juga untuk satu <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kamu <eos> pisau <eos> ini <eos> bung tidak <eos> kacamata lebih lubang anting <eos> <eos> <eos>
# chatbot: <unk>   apa yang kamu pikir waktu <eos> <eos> <eos> <eos> <eos> waktu <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   lalu kehilangan peternakan    di bank   dan kamu <eos> <eos> <eos> <eos>
# chatbot: <unk>   ayo kami mulai <eos> <eos> <eos> hal yang yang <eos> mengerti hanyalah <eos> ada <eos> <eos>
# Epoch: 01 | Time: 0m 4s
# 	Train Loss: 0.888 | Train PPL:   2.429
# chatbot: <unk>   mineral tidak keributan <eos> mengangkat tanganku dan <eos> <eos> pernah anak kursi ke <eos> tahun <eos>
# chatbot: <unk>   gadis baik   kebiasaan buruk <eos> di sini <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   ada itu telah menyebar ke seluruh <unk> dunia <eos> <eos> kontes <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   lihat apakah kamu bisa tahu apa yang mereka pikirkan itu pikirkan lihat yang itu <eos> <eos>
# chatbot: <unk>   tidak   mereka pendusta lahir <eos> <eos> <eos> kali <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   oh   jangan aku <eos> berbau kemah   begitu <eos> <eos> tidak <eos> <eos> <eos> <eos>
# chatbot: <unk>   kuberi tahu kalian iya   semua semua sama <eos> kawan sama tahu <eos> <eos> <eos> <eos>
# chatbot: <unk>   ada apa denganmu <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   annie   apa <eos> tuhan <eos> <eos> annie <eos> sini <eos> <eos> <eos> <eos> ini <eos> meredith <eos> <eos>
# chatbot: <unk>   aku rambut <eos> lainnya <eos> di <eos> itu <eos> itu si anak <unk> <eos>
# chatbot: <unk>   terimakasih <eos> <eos> <eos> <eos> nak <eos> <eos> <eos> <eos> <eos> <eos> <eos> harus <eos> <eos>
# chatbot: <unk>   dari   untuk memulai disidang   aku mempertahankan satu hidupku tidak <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   mari kami dengar dari sini <eos> <eos> dia dia <eos> mari <eos> dan <eos> <eos> <eos>
# chatbot: <unk>   kakekku baru kakekku adalah kakak dari direktur park dan karena itu   aku akan memberimu <eos>
# chatbot: <unk>   aku tidak <eos> <unk> <eos> dengarkan <eos>   aku tidak dapat liburan <eos> <eos> ditunjuk <eos>
# chatbot: <unk>   hi <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   hi dirimu bahwa ia <eos> <eos> <eos> <eos> terlihat <unk> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku mengerti kenapa kamu sensitiv <eos> <eos> <eos> sensitiv <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   apakah kamu tidak melihat wajahnya <eos> wajahnya <eos> <eos> <eos> kamu wajahnya <eos> <eos> <eos> <eos>
# chatbot: <unk>   coba pilih <eos> <eos> dan bukan <eos> <eos> tidak <eos> <eos> <eos> <eos> kan <eos> <eos>
# chatbot: <unk>   aku harus <eos> <eos> <eos> bukan <eos> <eos> <eos> ke ke <eos> <eos> <eos> pergi <eos>
# chatbot: <unk>   anak adalah bersalah <eos> <eos> <eos> tidak bersalah <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   lebih baik membuang senjata kamu <eos> baik <eos> <eos> <eos> <eos> <eos> <eos> baik <eos> <eos>
# chatbot: <unk>   kurasa <unk> musim karena ini <eos> <unk> <eos> <eos> <eos> <unk> <eos> <eos> <unk> <eos>
# chatbot: <unk>   apa nama <eos> <eos> <unk> penyerangan <eos> perampokan <eos> bola tenis <eos> kami <eos> <eos> tenis
# chatbot: <unk>   itu sinting <eos> hal <eos> <eos> <eos> <eos>     itu <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   tapi dalam mimpiku kamu dan presiden <eos> <eos> <eos> <eos> <eos> dalam <eos> <eos> <eos> <eos>
# chatbot: <unk>   lalu bagaimana dengan kakekmu <eos> lihat lalu lalu kakekmu <eos> ini <eos> lalu kakekmu <eos> kakekmu
# chatbot: <unk>   hallie sudah ceritakan hallie <eos> <eos> <eos> <eos> <eos> <eos> peringatan <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   dia masalah <eos> dari doc <eos> <eos> temanku dari jadi qe <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   pintunya <unk> menurut <unk>   ingat <eos> ingat <eos>   <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   davis <eos> <eos> <eos> <eos> <eos> kamu <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   belajarlah dari <unk>   freya   dan harimu akan datang <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> ke   tapi hari <eos> yang sama
# chatbot: <unk>   dia bercanda <eos> dia <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> dia <eos> <eos> <eos>
# chatbot: <unk>   lihatlah   hai   aku bernapas melalui hidung <eos> <eos> <eos> hidung <eos> <eos> <eos> <eos>
# chatbot: <unk>   oke seperti dipukul <eos> kepala dengan linggis hari sehari <eos> sehari hari <eos> <eos> <eos> <eos>
# chatbot: <unk>   dia harus berjalan berjalan berjalan ke   buka pintu kaki   berjalan kaki ke bawah <eos>
# chatbot: <unk>   apakah ada yang lebih lebih baik daripada kami <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kalau <eos> <unk> akau adalah menemukan cara untuk menyembunyikan <eos> ini <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku pikir ke hallie kalian ahli ahli kalian dia aku aku aku <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku   ke kanan <eos> dengan di di hari di parker <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   akan ada pembicaraan yang buruk tentangmu doc aku bersama doc mengapa holliday <eos> pembicaraan doc <eos>
# chatbot: <unk>   <unk> <eos> <eos> tidak tidak ada bisa kamu bisa bicara <eos> <eos> sesuatu <eos> <eos> <eos>
# chatbot: <unk>   <unk> dengan aku <eos> <eos> <eos> <eos> <unk> <eos> <eos> untuk <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   yeah <eos> ini <eos> <eos> <eos> <eos> <eos> <eos> kasus <eos> <eos> pertama <eos> <eos> <eos>
# chatbot: <unk>   ayo   bayi   cobalah untuk rileks <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   <unk> <eos> <eos> tidak bertemu <eos> ini tidak <eos> tidak untuk yang yang <eos> <eos> <eos>
# chatbot: <unk>   dengar   aku mendapatkan intel yang lebih dalam yang dalam ini <eos> <eos> <eos> <eos> yang
# chatbot: <unk>   aku   tuan mobilnya <eos> <eos> <eos>   tapi ada kami mendapatkan di <eos> <eos> <eos>
# chatbot: <unk>   bahwa tempat ini sedikit <eos> <eos> <eos> <eos> masalah ini <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku telah memikirkannya <eos> <eos> itu <eos> besar <eos> dalam <eos> itu <eos> <eos> <eos> <eos>
# chatbot: <unk>   dia benar   meskipun <eos> kamu <eos> <eos> <eos> <eos> <eos> meskipun <eos> <eos> meskipun <eos>
# chatbot: <unk>   satu   dua   tiga   empat   lima   enam   tujuh <eos>
# chatbot: <unk>   kata   orang tua di bawah apartemen <eos> itu <eos> <eos> <eos> apartemen <eos> pertama <eos>
# chatbot: <unk>   aku ditempat <eos> <eos> <eos> di kantornya vogue dan <eos> dan jika cantik <eos> <eos> <eos>
# chatbot: <unk>   jadi apa <eos> <eos> <eos> ini <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kamu tahu <eos> <eos> <eos> <eos> <eos> ini <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   nah   apa yang kami lakukan sekarang <eos> <unk> <eos> <eos> <eos> <unk> <eos> <eos> <eos>
# chatbot: <unk>   aku ingin bicara sesuatu padamu <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   anak yang bisnis yang pisau <eos> <eos> semacam p <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   itu siapa <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   apa dia pergi dengan tenang <eos> <eos> <eos> <eos> <eos> apa <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   jika aku tidak bisa dalam beberapa jam virge <eos> aku tidak bisa <eos> <eos> <eos> <eos>
# chatbot: <unk>   apa ibu tidak mau <eos> ibu <eos> ibu tidak <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   pertemuan sebelum adalah adalah ide dia <eos> <eos> <eos> <eos> dia <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   oh <eos> aku   kamu bertemu <eos> <eos> di lalu <eos> yang selalu <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku   <eos> <eos> <eos> <eos> hutang <eos>   <eos>   tidak tidak hari di untuk
# chatbot: <unk>   ibu menyukaimu <eos> <eos> <eos> di <eos> atau <eos> <eos> ini <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   apa yang harus dilakukan dengan apa <eos> <eos> <eos> <eos> dilakukan <eos> <eos> dilakukan <eos> <eos>
# chatbot: <unk>   tunggu lama hadiah <eos> parkour <eos> <eos> hadiah <eos> <eos> hadiah <eos> tunggu <eos> <eos> <eos>
# chatbot: <unk>   dan meningkatkan lebih lebih bayi seperti yang yang inginkan <eos> <eos> <eos> ini <eos> <eos> <eos>
# chatbot: <unk>   itu akan menjadi anak mereka   <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kamu akan mengganggu aku <eos> <eos> <eos> apa dirimu <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   jangan kaget   ok <eos> ok <eos> <eos> el <eos> <eos> <eos> kaget <eos> lagi <eos>
# chatbot: <unk>   cobalah <eos> <eos> untuk jaksa di <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> di <eos>
# chatbot: <unk>   dia mengatakan detik <eos> <eos> detik detik <eos> dia jam <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kami terlalu keras untuk orang yang ingin berumur panjang <eos> panjang <eos> <eos> panjang <eos> <eos>
# chatbot: <unk>   aku tidak akan berada di sekitar <eos> <eos> <eos> aku aku aku <eos> <eos> <eos> <eos>
# chatbot: <unk>   tidak   marva <eos> <eos> <eos> ini <eos> <eos> <eos> <eos> <eos> <eos> marva <eos> <eos>
# chatbot: <unk>   dia akan akan bertahan sendirian dengan pulang harus pulang <eos> pulang pulang <eos> <eos> <eos> pulang
# chatbot: <unk>   tidak <unk> <eos> <eos> <eos> dua <eos> <eos> sesuatu sebuah <eos> <eos> ini <eos> <eos> <eos>
# chatbot: <unk>   aku marva kulp   pimpinan perkemahan <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kamu kamu mengganti <eos> <eos> <eos> <eos> <unk> <eos> saja <eos> <eos> kami <eos> <eos> <eos>
# chatbot: <unk>   sejauh yang aku ketahui   itulah kesaksian yang paling penting <eos> paling penting <eos> <eos> <eos>
# chatbot: <unk>   <unk> itu selesaikan sketsa <eos>   lalu tidak pernah muda ke ke dalam <eos> dan <eos>
# chatbot: <unk>   bagaimana bilang   kamu bekerja untuk siapa <eos> <eos> <eos> <eos> <eos> <eos> di <eos> <eos>
# chatbot: <unk>   aku mengerti <eos> <eos> <eos> <eos> dan aku <eos> <eos> <eos> dan mereka <eos> <eos> <eos>
# chatbot: <unk>   siapa   terimakasih untuk <unk> <eos> <eos> <eos> <eos> <eos> <eos> itu <eos> <eos> <eos> <eos>
# chatbot: <unk>   lepaskan <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kamu   gut up <eos> <eos> akan membuat kamu <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku usiamu <eos>   masih <eos> <eos> saja saja <eos> <eos> merasa apapun saja <eos> untuk
# chatbot: <unk>   kamu akan <eos> <eos> <unk> harus <eos> pergi <eos> iya mulai <eos> <eos> <eos> <eos> kamu
# chatbot: <unk>   kami sudah selesai dengan diagram ini <eos> hidupku <eos> <eos> <eos> ini <eos> <eos> <eos> <eos>
# chatbot: <unk>   siapa yang ingin memulai it off <eos> <eos> <eos> yang <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   anjing puppy <eos> boneka <eos> boneka ini <eos> <eos> <eos> <eos> <eos> boneka <eos> <eos> <eos>
# chatbot: <unk>   kamu pikiran dua berlalu menjatuhkan kerajaan raja <eos> <eos> ini <eos> dan <unk> <eos> <eos> <eos>
# chatbot: <unk>   dia pergi ke as <eos> <eos> aku <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   maksudku   mungkin saja <eos> <eos> <eos> <eos> mungkin tanganmu <eos> ekonomi <eos> <eos> <eos> <eos>
# chatbot: <unk>   pembohong <eos> <eos> <eos> bersih pembohong pembohong <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku <eos> <eos> <eos> <eos> dengarkan di <eos> mereka dan dan di bagian <eos> <eos> <eos>
# chatbot: <unk>   aku <eos> berada <eos> <eos> itu itu itu tangan <eos> karena <eos> <eos> <eos> <unk> <eos>
# chatbot: <unk>   tentu saja <eos> <eos> <eos> kesempatan harusnya hidupku <eos> <eos> <eos> kesempatan <eos> kamu <eos> <eos>
# chatbot: <unk>   pesan mendengar lagi kasih <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   oh   aku akan menunggu wyatt <eos> jika <eos> <eos> <eos> <eos> sendiri <eos> <eos> <eos>
# chatbot: <unk>   itu seperti sekali linggis linggis setiap hari <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kamu bisa memikirkannya setelah kamu menikah <eos> <eos> <eos> setelah <eos> <eos> <eos> inci <eos> <eos> <eos> setelah <eos>
# chatbot: <unk>   sorry <eos> <eos> <eos> <eos> tapi <eos> bisa <eos> <eos> <eos> itu <eos> <eos> <eos> sorry
# chatbot: <unk>   dia <unk> <unk> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kamu <eos> <eos> kami bertaruh <eos> <eos> hal   kami lain ini <eos> aneh
# chatbot: <unk>   kamu yakin <eos> argumen <eos> jatuh <eos> kami <eos> cam <eos> <eos> <eos> <eos> kan <eos>
# chatbot: <unk>   jika kamu kamu <eos> <unk> <eos> harus <eos> <eos> harus menikahinya <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kamu <unk> pernikahannya <eos> saja minggu minggu " <eos> <eos> pergi <eos> " " <eos> lagi
# chatbot: <unk>   apa maksudnya <eos> <eos> <eos> <eos> dan <eos> <eos> <eos> oke <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   kamu <unk>   <eos> tumbuh <eos> <eos> <eos> <eos> sarapan dan dan tahu <eos> <eos> <eos>
# chatbot: <unk>   kamu pasang enam <eos> <eos> perum bumi rancaekek kencana   bandung melihat keluar <eos> <eos>
# chatbot: <unk>   maaf   mata biru <eos> <eos> <eos> mata <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   itu adalah sesuatu yang tidak akan mengerti olehmu <eos> <eos> <eos> <eos> akan <eos> <eos> <eos>
# chatbot: <unk>   aku <eos> <eos> <eos> <eos> <eos> <eos> <unk> <eos> di <eos> <eos> di utara <eos> <eos>
# chatbot: <unk>   hotel <unk> <eos> sensitif doc <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   apa yang dia <unk> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos> <eos>
# chatbot: <unk>   aku   <eos> bersalah <eos> <eos> <eos> <eos> <eos> membunuh lain di tingkat <unk> <eos> <eos>
# chatbot: <unk>   iya   aku tahu aku tidak meminta salah satu dari kamu untuk membawanya ke sana <eos>
# chatbot: <unk>   saat <unk> berusia beberapa minggu     <eos> <eos> saat <eos> <eos> minggu <eos> <eos> <eos>
# chatbot: <unk>   aku <eos> <eos> <eos> <eos> <eos> di <eos> ke <eos> dan gadis tahu <eos> <eos> <eos>
# Epoch: 02 | Time: 0m 4s
# 	Train Loss: 0.910 | Train PPL:   2.484
# <All keys matched successfully>

# %%
talk(5)
# Out:
# user:  Good morning
# chatbot: <unk>   au revoir
# user:  Hello
# chatbot: <unk>   aku
# user:  Selamat pagi
# chatbot: <unk>   tidak <eos>
# user:  Kamu siapa
# chatbot: <unk>   seperti <eos>
# user:  Selamat siang
# chatbot: <unk>   kemasi <eos>
